# %% [markdown]
# Set & Dictionary

# %%
# Both are mutable data types
# set- {at least one element inside}

# %%
s = {}
type(s)
# Out:
# dict

# %%
s1 = {1,}
type(s1)
# Out:
# set

# %%
# Features of set
# duplicates are not allowed
p = {1,2,3,4,1,1,1,3,3,3,4,4,2,2,2,}
p
# Out:
# {1, 2, 3, 4}

# %%
# Does',t preserves sequence order
p = {1,290,'3',4,'A',1,1,3,3,3,4,'B','python',2,2,0}
p
# Out:
# {0, 1, 2, 290, '3', 3, 4, 'A', 'B', 'python'}

# %%
# Background data structure of a set is a hash Table
#  Hash table support indexing and slicing

# %%
# Set is mutable in nature
s = {'Za11.5','Ba','Ab','C',2,2,'299',2,1,1,1,3,3,3,3,5,4,4,4,9,9,9,7,8,8}
s
# Out:
# {1, 2, '299', 3, 4, 5, 7, 8, 9, 'Ab', 'Ba', 'C', 'Za11.5'}

# %%
# try to delete members of a set
s.pop()
# Out:
# 1

# %%
s
# Out:
# {2, '299', 3, 4, 5, 7, 8, 9, 'Ab', 'Ba', 'C', 'Za11.5'}

# %%
s.pop()
# Out:
# 2

# %%
s
# Out:
# {'299', 3, 4, 5, 7, 8, 9, 'Ab', 'Ba', 'C', 'Za11.5'}

# %%
s.pop()
# Out:
# 3

# %%
lot= {1122,3122,4355,6711,2934}

# %%
winner = lot.pop()
winner
# Out:
# 4355

# %%
lot
# Out:
# {2934, 3122, 6711}

# %%
print('Original lot:',lot)
out = lot.pop()
print('Element removed:', out, 'Current set:',lot)
# Out:
# Original lot: {3122, 2934, 6711}
# Element removed: 3122 Current set: {2934, 6711}

# %%
# remove(value)
help(s.remove)
# Out:
# Help on built-in function remove:
#
# remove(...) method of builtins.set instance
#     Remove an element from a set; it must be a member.
#
#     If the element is not a member, raise a KeyError.

# %%
p
# Out:
# {0, 1, 2, 290, '3', 3, 4, 'A', 'B', 'python'}

# %%
p.remove(4)

# %%
p
# Out:
# {0, 1, 2, 290, '3', 3, 'A', 'B', 'python'}

# %%
# if we try to remove an element which is not present
p.remove('java')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_14029/1947858643.py in <cell line: 0>()
#       1 # if we try to remove an element which is not present
# ----> 2 p.remove('java')
#
# KeyError: 'java'

# %%
x = {'A','B','c'}
x
# Out:
# {'A', 'B', 'c'}

# %%
# pop()
x.pop() # return an element which it remove
# Out:
# 'A'

# %%
x
# Out:
# {'B', 'c'}

# %%
x.remove('A')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_14029/1616679330.py in <cell line: 0>()
# ----> 1 x.remove('A')
#
# KeyError: 'A'

# %%
fx.remove('c') # it is not returning, just removes it

# %%
x
# Out:
# set()

# %%
a= [1,2,3,4,1,1,2,2,3,3]
a
# Out:
# [1, 2, 3, 4, 1, 1, 2, 2, 3, 3]

# %%
set(a)
# Out:
# {1, 2, 3, 4}

# %%
tuple(a)
# Out:
# (1, 2, 3, 4, 1, 1, 2, 2, 3, 3)

# %%
per_day = float(input('Enter your per day income:Rs'))
days = float(input('working days:'))
print('Fianl Salary is Rs.',per_day*days)
# Out:
# Enter your per day income:Rs1222
# working days:20.5
# Fianl Salary is Rs. 25051.0

# %%
data = eval(input('Enter your data'))

print(data)
print(type(data))
# Out:
# Enter your data{2:200,3:300}
# {2: 200, 3: 300}
# <class 'dict'>
