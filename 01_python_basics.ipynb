# %% [markdown]
# Basics of python

# %% [markdown]
# Different types of Data type

# %%
# 14 Data types
# Numeric: int,float,complex
# Boolean: True Flase
# String
# List
# Tuple
# Set
# Dict
# Frozenset
# None
# Bytes
# Bytearray
# range

# %%
# Python is Dynamically types language
# Static typing- int a = 20 | string s ='python'
# Dynamic Typing- a = 20| s = 'python'
a = 220
type(a)
# Out:
# int

# %%
s = 'python'
type(s)
# Out:
# str

# %%
a.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1450/2984306047.py in <cell line: 0>()
# ----> 1 a.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
x ='python'
type(x)
# Out:
# str

# %%
x = 10
type(x)
# Out:
# int

# %%
id(x)
# Out:
# 11645640

# %%
id(10)
# Out:
# 11645640

# %%
y = 10
id(y)
# Out:
# 11645640

# %%
id('python')
# Out:
# 137923608804304

# %%
p = 'python'
id (p)
# Out:
# 137923608804304

# %%
q = 'python'
id(q)
# Out:
# 137923608804304

# %%
e = [1,2,3]
id(e)
# Out:
# 137922941518528

# %%
t = [1,2,3]
id(t)
# Out:
# 137922939504704

# %%
# String in Python
# syntax: '' ""

# %%
type ('.net')
# Out:
# str

# %%
type("c++")
# Out:
# str

# %%
# List
# syntax: []
q = [1,2,3] # homo.
r = ['A','B','c'] # homo
p = ['X',10,22,22,'Y'] # hetro

# %%
# Tuple
# syntax: ()
t1 = (1,2,3)
t2 = ('A','B','C') # homo
t3 = ('x',10,22,22,'y') # hetro

# %%
type(t1),type(t2),type(t3)
# Out:
# (tuple, tuple, tuple)

# %%
p #list
# Out:
# ['X', 10, 22, 22, 'Y']

# %%
t2 # tuple
# Out:
# ('A', 'B', 'C')

# %%
# list[] vs tuple()
# list is mutable - means we can change the list
p.append(200)
p
# Out:
# ['X', 10, 22, 22, 'Y', 200]
