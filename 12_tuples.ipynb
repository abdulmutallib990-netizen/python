# %%
t = () # empty tuple

# %%
type(t)
# Out:
# tuple

# %%
# Tuple has same features as that of list
# It accepts homo./hetro. data

# %%
a = (1,2,3,4) # data is of same type---> homo.
b = (1,23.22,4+5j,'viany') # data is of different type--->hetro

# %%
a
# Out:
# (1, 2, 3, 4)

# %%
b
# Out:
# (1, 23.22, (4+5j), 'viany')

# %%
  # Tuple supports indexing and slicing bcz background data structure is an Array

# %%
b[1:3]
# Out:
# (23.22, (4+5j))

# %%
# Tuple preserves sequence order
# duplicates are allowed in tuple
# Tuple is Immutable in nature
# ----------------------------------
# In data type we have 2 approaches
# 1. Mutable data types- i which we can directly perform the changes(add,update, remove,insert,del)
# Ex. List,Set,Dict
# 2.Immutable data types- in which we can't perform the change in the original object, change remain temp.
# Ex. Tuple,String,Range

# %%
p =[10,20,30]
p
# Out:
# [10, 20, 30]

# %%
# list is mutable
# lets try to change last element 30
p[-1] ='Akshay'

# %%
p
# Out:
# [10, 20, 'Akshay']

# %%
p[-2] = 400

# %%
p
# Out:
# [10, 400, 'Akshay']

# %%
p[-1] = 'Abdul'
p
# Out:
# [10, 400, 'Abdul']

# %%
# remove
p.remove(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_756/2991054765.py in <cell line: 0>()
#       1 # remove
# ----> 2 p.remove(10)
#       3 p
#
# ValueError: list.remove(x): x not in list

# %%
p
# Out:
# [400, 'Abdul']

# %%
# use insert(index,value) to add an element using index
p.insert(0,'LAXMI')

# %%
p
# Out:
# ['LAXMI', 400, 'Abdul']

# %%
p.insert(-1,'habib nagar')

# %%
p
# Out:
# ['LAXMI', 400, 'habib nagar', 'Abdul']

# %%
# lets try to understand Immutable concept
# in which user can't able to change in the original object

t = (10, 20, 30)
t
# Out:
# (10, 20, 30)

# %%
# lets relace last element
t[-1] = 'shridhar'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_756/1118699104.py in <cell line: 0>()
#       1 # lets relace last element
# ----> 2 t[-1] = 'shridhar'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.remove(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_756/4018256599.py in <cell line: 0>()
# ----> 1 t.remove(20)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
p.insert(0,'babu')

# %%
# Assignment: Tuple contain 2 method- count(object) and index(object) check these 2 method

# %%
# Tuple Packing and Unpacking
a = 100
b = 200
c = 300

# %%
# packing:combine segregated/ seprated elements as a one entity
a,b,c
# Out:
# (100, 200, 300)

# %%
nums = a,b,c

# %%
nums
# Out:
# (100, 200, 300)

# %%
# Unpacking- It is a process of seprating the individual object ans store it in seprate variable called
num1,num2,num3= nums

# %%
num1
# Out:
# 100

# %%
num3
# Out:
# 300

# %%
# Assignment: Check packing and unpacking for list as well
