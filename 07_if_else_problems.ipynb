# %%
# 1. Write a Python program to find maximum between two numbers
a = [1,2,3,4,56,7,85,34,76]


for num in a:
  if num> maximum:
    maximum = num
  print('Maximum no.',maximum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3513/4182108560.py in <cell line: 0>()
#       4
#       5 for num in a:
# ----> 6   if num> maximum:
#       7     maximum = num
#       8   print('Maximum no.',maximum)
#
# NameError: name 'maximum' is not defined

# %%
oa
# Out:
# [1, 2, 3, 4, 56, 7, 85, 34, 76]
