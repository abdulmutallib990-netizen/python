# %% [markdown]
# Flow control blocks
#
#    Iterative statements

# %%
# for var in sequence
# indented block - 2 spaces/4spaces

# %%
# it is used to fetch the elements from collection ONE by ONE

nums = ['vandana','sarita','tauzi','prasad','pratik']
for n in nums:
  print(n.upper())
# Out:
# VANDANA
# SARITA
# TAUZI
# PRASAD
# PRATIK

# %%
for n in nums:
  if n.endswith('a'):
    print(n.upper())
# Out:
# VANDANA
# SARITA

# %%
nums
# Out:
# ['vandana', 'sarita', 'tauzi', 'prasad', 'pratik']

# %%
# fetch names in which i is present

for n in nums:
  if 'i' in n:
    print(n.title())
# Out:
# Sarita
# Tauzi
# Pratik

# %%
'n' in 'sarita'
# Out:
# False

# %%
nums
# Out:
# ['vandana', 'sarita', 'tauzi', 'prasad', 'pratik']

# %%
# fetch names whose length is <= 5

for n in nums:
  if len(n)<=5:
    print(n)
# Out:
# tauzi

# %%
num = [23,10,70,45,90,100,35,7,8,16]
# fetch nmbers divible by 5 and 7

for n in num:
  if (n%5==0) and(n%7 == 0):
    print(n)
# Out:
# 70
# 35

# %%
for n in num:
  if (n%5 == 0)or (n%7 == 0):
    print(n)
# Out:
# 10
# 70
# 45
# 90
# 100
# 35
# 7

# %%
# assignment:
k = [1,1,1,2,2,3,4,5]
# I want to fetch most frequent numbers from the list
K = [1,1,1,2,2,2,3,4,5]

for num in K:
    if K.count(num) == max_freq:
      print("Most frequent:", num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3430/3426748207.py in <cell line: 0>()
#       5
#       6 for num in K:
# ----> 7     if K.count(num) == max_freq:
#       8       print("Most frequent:", num)
#
# NameError: name 'max_freq' is not defined

# %%
# Patern programs
"""
*
**
***
****
*****
******
"""
for n in range(1,7):
  print(n*'* ')  #range(start,stop)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *

# %%
#above payterb in reverse
for n in range (6,0,-1):
  print(n*'* ')
# Out:
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
tuple (range(6,0,-1))
# Out:
# (6, 5, 4, 3, 2, 1)

# %%
# alphabate pattern

chr(65)
# Out:
# 'A'

# %%
ord('<')
# Out:
# 60

# %%
for n in range(6,0,-1): #range(start,stop,step)
  print(chr(n+64))
# Out:
# F
# E
# D
# C
# B
# A

# %%
for i in range(1,7):  #3
  for j in range(i):  #range(3)
    print(chr(i+64),end="")
  print(end="\n\n")  # new line/next line
# Out:
# A
#
# BB
#
# CCC
#
# DDDD
#
# EEEEE
#
# FFFFFF

# %%
list(range(3)) # stop
# Out:
# [0, 1, 2]

# %%
for i in range (3):
  print(i,end='')
# Out:
# 012
