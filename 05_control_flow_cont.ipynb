# %% [markdown]
# Flow control block
#
#
# 1.   Selective/ conditional statement
#
# 2.   Iterative statements
#
# 3.  Transfer statements

# %%
# 1. Selective statement
# these statements are conditional based
# we se conditional operators to check or compare the objects
# Conditional operators - < > <= >= == != these operator generate boolean answer means True False

# in order to use these statement/block we have if elif else

# %%
# when user wants to test single condition then use only if <condition>:

# %%
name = 'arti'

if name =='arti':
  print('Good Morning')
# Out:
# Good Morning

# %%
# if condition results is True ur program control will enter inside the block

# %%
# if condition result is true then ur program control will enter inside the block

# %%
# if we want to check 2 condition in one if block then use operators (and,or, not)

age = 66
 # int(input('enter your age'))
country ='india'

if age >= 18 and country== 'india':
  print("You are eligible to vote")
else:
  print("You are not eligible to vote")
# Out:
# You are eligible to vote

# %%
# if for one check
# if else for 2 check
# if user want  to check more than 2 option then use elif

#amt = 120000
#amt= 99999
amt = 45000

# whenever user takes a block in python is ends with : and at the next line
# you body of the block starts
# all statements we write inside that block. The space infort of the each statements is called as
# Indentation
if amt >100000:
  print('Purchase iphone')
elif amt > 90000:
  print('Purchase Sumsung/Vivo/Realme phones')
elif amt > 50000:
  print('Purchase Oppo/ Lava...etc Phones')
else:
  print('You can try with reamining options..')
# Out:
# You can try with reamining options..

# %%
# 2. Iterative statement
# It contain2 loops
# 1. for loop
# 2. while loop

# %%
#for loop : isn an iterative loop which fetches one element at a time from the collection inside the body of the loop
a = [10,20,30,40]

#syntax for var in collection/iterable

for val in a[::-1]:
  print(val)
# Out:
# 40
# 30
# 20
# 10

# %%
name = 'vandana'
for i in name:
  print(i)
# Out:
# v
# a
# n
# d
# a
# n
# a
