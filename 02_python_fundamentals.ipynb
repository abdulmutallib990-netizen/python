# %% [markdown]
# Data Types in Python

# %%
# Set
#syntax: {at least one element}

type({})
# Out:
# dict

# %%
type({12})
# Out:
# set

# %%
a = {1,2,3,4}
a
# Out:
# {1, 2, 3, 4}

# %%
b = {1,'A', 3.44,'Python'}
b
# Out:
# {1, 3.44, 'A', 'Python'}

# %%
# dist
# syntax: {key:value}

d1 ={1:100,2:200,3:300}
d1
# Out:
# {1: 100, 2: 200, 3: 300}

# %%
type(d1)
# Out:
# dict

# %% [markdown]
# String

# %%
# String is Immutable data type
# we can not change the string ones it is created and we cant modify or update the string

# %%
#string backgroud data structure is an Array
# array is a collection of sequential elements
# s = 'python'
# p---> 0
# y---> 1
# t--->2
# so no

# %%
s = 'PYTHON'

#indexing access only single element at a time
s[-1]
# Out:
# 'N'

# %%
len(s)//2 #5.66
# Out:
# 3

# %%
# Indexing is of 2 types
# +ve indexing ----> starts with 0 and ends at (n-1) n means total chars/block (left to right)
# -ve indexing ----> starts with -1 and ends at -n (right to left)

# %%
# Slicing
# using this we can access more than one element

# %%
s
# Out:
# 'PYTHON'

# %%
s[2:-1] # [start:stop] # stop is exclusive means element at this index position will not be in the output
# Out:
# 'THO'

# %%
# Access PY
# Access YTH
# Access HO

# %%
s[:2]
# Out:
# 'PY'

# %%
s[1:4]
# Out:
# 'YTH'

# %%
s[3:5]
# Out:
# 'HO'

# %%
addrs = 'Jawahar Nager Kolhapur pin- 411012'
addrs[-6:]
# Out:
# '411012'

# %%
s[::2]
# Out:
# 'PTO'

# %%
#[start:stop:step]

n = 'vandana koli'
# reverse the string

n[::-1]
# Out:
# 'ilok anadnav'

# %%
n[1::-1]
# Out:
# 'av'

# %%
# Assignment
p = 'I love my India'
# Access my , India, I love, ove, love my, my India

# %%
p[6:9],p[-6:],p[:-8],p[2:9],p [3:6],p[-8:]
# Out:
# (' my', ' India', 'I love ', 'love my', 'ove', 'my India')

# %% [markdown]
# String Methods

# %%
s
# Out:
# 'PYTHON'

# %%
# convert str in lower case
s.lower()
# Out:
# 'python'

# %%
# Capitalize () method
s.capitalize()
# Out:
# 'Python'

# %%
'gorakh shinde'. title()
# Out:
# 'Gorakh Shinde'

# %%
# to remove spaces present in prefix and suffix use strip () method
'       python      '.strip() # default strip removes spaces
# Out:
# 'python'

# %%
'****JAVA** $$***'.strip('*$ ')
# Out:
# 'JAVA'

# %%
# Assigment: remove spaces present in between
'      J     A      9999 V  7777    A'.replace(' ','')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_8874/694880959.py in <cell line: 0>()
#       1 # Assigment: remove spaces present in between
# ----> 2 '      J     A      9999 V  7777    A'.replace(' ','').pop()
#
# AttributeError: 'str' object has no attribute 'pop'

# %%
'  %&Python**'.strip(' %*&')
# Out:
# 'Python'

# %%
# Assignment: Check casefold()
# what is difference between casefold() and lower()

# %%
# When we want to convert lower to upper and vice versa use swapcasea()

h = 'gooD MorniNG'
h.swapcase()
# Out:
# 'GOOd mORNIng'

# %%
code = 'cbr1-assddfakfhfkjghfkjlnkcmxnvzhioweiuri'
code.startswith('cbr') # it will return boolean output
# Out:
# True

# %%
code .endswith('ABC')
# Out:
# False

# %%
#join () is used to prepare a string using a collection

adhar = 'PYTHON'
# prepare a str of adhar

'--'.join(adhar)
# Out:
# 'P--Y--T--H--O--N'

# %%
adhar = ['1234','4567','6789']
# prepare a str of adhar

'--'.join(adhar)
# Out:
# '1234--4567--6789'

# %%
code.
