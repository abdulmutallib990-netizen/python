# %% [markdown]
# List Method

# %%
# syntax: []

# %%
# Features of list
# Backgroumd data structure - Array
# It supports Indexing and slicing
# It accepts all types of data
# It preserves sequence order
# We can create homo. and hetro. list
# It allowes duplicates records
# list is mutable in nature
# Q. Explain feauteres of a list

# %%
help(list.append)
# Out:
# Help on method_descriptor:
#
# append(self, object, /) unbound builtins.list method
#     Append object to the end of the list.

# %%
# How to create an empty list
a = []
a
# Out:
# []

# %%
#2
b = list() # function
b
# Out:
# []

# %%
#Assignment: How to create an empty string
M = str()
M
# Out:
# ''

# %%
a
# Out:
# []

# %%
# To add elements in empty list/ a normal then use append(object) method
a.append(100)

# %%
# Operation in list are inpalce/permnt.

# %%
# Assignment: try to add str, list, tuple, set, dict

# %%
a
# Out:
# [100]

# %%
data = (2,3,4)
data
# Out:
# (2, 3, 4)

# %%
# add above data in a
a.append(data)  #This will add a complete tuple in a
a
# Out:
# [100, (2, 3, 4)]

# %%
#add c++
a.append('c++')
a
# Out:
# [100, (2, 3, 4), 'c++']

# %%
# append adds a complete object as it is

# %%
# use extend() to add individual elements from an iterable(collection of elements)
b
# Out:
# []

# %%
b.extend(data)
b
# Out:
# [2, 3, 4]

# %%
b.extend('c++')
b
# Out:
# [2, 3, 4, 'c', '+', '+']

# %%
# Q append vs extend

# %%
# to remove elements from list we have 2 methods
# pop(default removes last element)
b
# Out:
# [2, 3, 4, 'c', '+', '+']

# %%
b.pop()
# Out:
# '+'

# %%
b
# Out:
# [2, 3, 4, 'c', '+']

# %%
a
# Out:
# [100, (2, 3, 4), 'c++']

# %%
a.pop()
# Out:
# 'c++'

# %%
a
# Out:
# [100, (2, 3, 4)]

# %%
# pop default removes last element

# %%
k = [1,2,3,4,5,6,7]
k
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
# pop(index)--> we can remove element with its index
k.pop(2)
# Out:
# 3

# %%
k
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
help(k.pop)
# Out:
# Help on built-in function pop:
#
# pop(index=-1, /) method of builtins.list instance
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %%
#remove(value)
k
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
k.remove(6)

# %%
k
# Out:
# [1, 2, 4, 5, 7]

# %%
help(k.remove)
# Out:
# Help on built-in function remove:
#
# remove(value, /) method of builtins.list instance
#     Remove first occurrence of value.
#
#     Raises ValueError if the value is not present.

# %%
t = [1,2,3,1,1,4,5,1,1]
t.remove(1)

# %%
t
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1]

# %%
k
# Out:
# [1, 2, 4, 5, 7]

# %%
# remove all elements
k.clear()
k
# Out:
# []

# %%
t
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1]

# %%
# shallow copy- list is with samw element but ids are diffrent

x = t.copy()
x
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1]

# %%
#add -1 in x
x.append(-1)
x
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1, -1]

# %%
t
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1]

# %%
id(t),id(x)
# Out:
# (138635011267264, 138635011297152)

# %%
y =x
y
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1, -1]

# %%
x
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1, -1]

# %%
# in above case we have 1 object with different names x,y hence
# if we change in either x/y changes will get reflected in both the list
x.append('python')
x
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1, -1, 'python']

# %%
y
# Out:
# [2, 3, 1, 1, 4, 5, 1, 1, -1, 'python']

# %%
r1 =[]
r1
# Out:
# []

# %%
r2 = r1
r2
# Out:
# []

# %%
r1.append(500)

# %%
r2
# Out:
# [500]

# %%
r2.extend([20,30])
r2
# Out:
# [500, 20, 30]

# %%
r1
# Out:
# [500, 20, 30]

# %%
id(r1),id(r2)
# Out:
# (138635011261760, 138635011261760)

# %%
# Assignement: can we add a tuple to a list using extend?
