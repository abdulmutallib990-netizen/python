# %% [markdown]
# Revision of Set

# %%
s = { 10,230,4,-11,10,10,4,4,4,}
s
# Out:
# {-11, 4, 10, 230}

# %%
# dupicates not allowed in set
# it dosen't preserves order

# this is bcz of background data structure- Hash Table

# Indexing and slicing not supported

# %%
# bucket number--> hash value
-11%2
# Out:
# 1

# %%
help(set.pop)
# Out:
# Help on method_descriptor:
#
# pop(...) unbound builtins.set method
#     Remove and return an arbitrary set element.
#     Raises KeyError if the set is empty.

# %%
s
# Out:
# {-11, 4, 10, 230}

# %%
s.pop()
# Out:
# 10

# %%
s
# Out:
# {-11, 4, 230}

# %%
# can we add index here
s.pop(-1) # set pop is with no args.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_945/3873078807.py in <cell line: 0>()
#       1 # can we add index here
# ----> 2 s.pop(-1) # set pop is with no args.
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
# how to create an empy set

d = set()
d
# Out:
# set()

# %%
type(d)
# Out:
# set

# %%
help(set)
# Out:
# Help on class set in module builtins:
#
# class set(object)
#  |  set() -> new empty set object
#  |  set(iterable) -> new set object
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
# ...

# %% [markdown]
# Typecasting/Type conversion
#
# *   we as a user wants to change a data type from one from to another
#
# * ex.liat--->tuple| tuple---> set

# %%
a = [1,2,3,4,5,1,1,1,2,2,3,3]
a
# Out:
# [1, 2, 3, 4, 5, 1, 1, 1, 2, 2, 3, 3]

# %%
# write a program to remove the duplicates
set(a) # temp.
# Out:
# {1, 2, 3, 4, 5}

# %%
tuple(a)
# Out:
# (1, 2, 3, 4, 5, 1, 1, 1, 2, 2, 3, 3)

# %%
# take an input from the user

per_day = float(input('Enter your per day income:Rs.'))

# print(type(perday))
days = float(input('Working days'))

print('Final Salary is Rs.',per_day*days)
# Out:
# Enter your per day income:Rs.1234
# Working days23
# Final Salary is Rs. 28382.0

# %%
# Assignment: Creatae a simple of grocery. Take 3-4 input and print the final bill
name = (input("item Name: "))
price = float(input("Price: "))
quantity =(input('Qauntity: '))
# Out:
# item Name: Rice
# Price: 85
# Qauntity: 4kg

# %%
int('100')
# Out:
# 100

# %%
float('34.55')
# Out:
# 34.55

# %%
# Ps: take an input list/ set/tuple/dict from the user
# eval() function will help you to take the data in its original format

data = eval(input('Enter ypur data:'))

print(data)
print(type(data))
# Out:
# Enter ypur data:{1:20,2:40,3:60}
# {1: 20, 2: 40, 3: 60}
# <class 'dict'>

# %%
'vandana', 'snehal'
# Out:
# ('vandana', 'snehal')

# %%
# Rule- comma separated values in python ar daefault tupel

# %%
12.33,45.44,6,66
# Out:
# (12.33, 45.44, 6, 66)

# %%
# Take a dict and appy for loop
f = {1:20,2:40,3:60}
for val in f:
  print(val,f[val])
# Out:
# 1 20
# 2 40
# 3 60

# %%
f[2]
# Out:
# 40

# %%
f
# Out:
# {1: 20, 2: 40, 3: 60}

# %%
f.items()
# Out:
# dict_items([(1, 20), (2, 40), (3, 60)])

# %%
for val in f.items():
  print(val)
# Out:
# (1, 20)
# (2, 40)
# (3, 60)

# %%
num1,num2 = (1,100) #tuple unpacking

# %%
num1
# Out:
# 1

# %%
num2
# Out:
# 100

# %%
for key,val in f.items():
  print(key,val)
# Out:
# 1 20
# 2 40
# 3 60
