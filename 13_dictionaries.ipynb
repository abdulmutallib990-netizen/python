# %% [markdown]
# Dictionary

# %%
a = {1,} #empty dict
type(a)
# Out:
# set

# %%
# set vs dict
# set is a colletion of objects separated by comma,
# dict is a collection of key:value pairs

# %%
b = {1:100,2:200,3:300}
b
# Out:
# {1: 100, 2: 200, 3: 300}

# %%
c = {'name':'python','age':36,2:22.2}
c
# Out:
# {'name': 'python', 'age': 36, 2: 22.2}

# %%
# Features of dict
# duplicate keys are not allowed
g = {1:10, 1:1000,1:'java'}
g
# Out:
# {1: 'java'}

# %%
# Rule- if we have multiple values with same key present in the dict then it takes last recent pair
# in above case 1:'java is the last key value pair

# %%
# Iterable: collection of elements, we have more than oe element

# %%
h= {1:10,[2,4]:1000,3:'java'} # here we are trying to set a list as a key which is not allowed-check below rule
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2998/1172215142.py in <cell line: 0>()
# ----> 1 h= {1:10,[2,4]:1000,3:'java'} # here we are trying to set a list as a key which is not allowed-check below rule
#
# TypeError: unhashable type: 'list'

# %%
# in a set we can not give/add MUTABLE object
# &in dict we can not set key as a mutable object
# duplicate value are allowed
t = {'Abdul':100,2:100,'babu':100}
t
# Out:
# {'Abdul': 100, 2: 100, 'babu': 100}

# %%
u = {1:'python',2:'python',3:'python'}
u
# Out:
# {1: 'python', 2: 'python', 3: 'python'}

# %%
# Methods of dict

# %%
# Dict is Mutable

# %%
# create an empty dict
x = {}
x
# Out:
# {}

# %%
# add pair/s
x.update({1:10,2:20})

# %%
x
# Out:
# {1: 10, 2: 20}

# %%
# we can also use update to update already existing value of concerned key
x.update({2:'sql'})
x
# Out:
# {1: 10, 2: 'sql'}

# %%
# we can also use setdefault method
help(x.setdefault)
# Out:
# Help on built-in function setdefault:
#
# setdefault(key, default=None, /) method of builtins.dict instance
#     Insert key with a value of default if key is not in the dictionary.
#
#     Return the value for key if key is in the dictionary, else default.

# %%
x.setdefault(4) # for key 4 it will add None as a Value 4:None

# %%
x
# Out:
# {1: 10, 2: 'sql', 4: None}

# %%
# instead to None we want another value
x.setdefault(5,'ABC')
# Out:
# 'ABC'

# %%
x
# Out:
# {1: 10, 2: 'sql', 4: None, 5: 'ABC'}

# %%
# if key is already present n we try to give a new value or if we keep it empty
x.setdefault(5) # IF KEY already exist in the dict, then setdefault returns its value, it wont update it to None
x
# Out:
# {1: 10, 2: 'sql', 4: None, 5: 'ABC'}

# %%
# To fetch keys only
x.keys()
# Out:
# dict_keys([1, 2, 4, 5])

# %%
 # To fetch values only
x.values()
# Out:
# dict_values([10, 'sql', None, 'ABC'])

# %%
# fetch (key'value)
x.items()
# Out:
# dict_items([(1, 10), (2, 'sql'), (4, None), (5, 'ABC')])

# %%
# Assignemt: Check remaining methods f dict
